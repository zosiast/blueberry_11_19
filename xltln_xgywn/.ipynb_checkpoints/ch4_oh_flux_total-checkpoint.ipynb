# %%
import netCDF4 as nc
import pylab as plt
import numpy as np
from mpl_toolkits.basemap import Basemap, shiftgrid
import cf
import cfplot as cfp
import matplotlib
import numpy.ma as MA

# %%
#constants
mr_ch4 = 16
per_sec_to_per_yr = 60*60*24*360
g_to_Tg = 1e12

# %% [markdown]
# ## Import xltln data with emissions included

# %%
data_flux = nc.Dataset('/shared/netscratch/ptg21/UM_data/xltln/xltln_ch4+oh.nc')
#extract variables to arrays
ch4_oh = data_flux.variables['ch4+oh'][:] #moles per second
lat = data_flux.variables['latitude']
#lon = data.variables['longitude'][:]
#alt = data.variables['level_height'][:]

#ch4_oh, lon = shiftgrid(180.,ch4_oh,lon,start=False)

# %%
press_xl_data = nc.Dataset('/shared/netscratch/ptg21/UM_data/xltln/xltln_p.nc')
press_xl = press_xl_data.variables['p']

# %%
trop_press_xl_data = nc.Dataset('/shared/netscratch/ptg21/UM_data/xltln/xltln_troppres.nc')
trop_press_xl = trop_press_xl_data.variables['trop_p']

# %%
#mass_data = nc.Dataset('/shared/netscratch/ptg21/UM_data/xltln/xltln_airmass.nc')
#mass = mass_data.variables['airmass_atm']

# %%
time = data_flux.variables['time']
dtime = nc.num2date(time[:],time.units)

# %% [markdown]
# ## Import fixed LBC data

# %%
data_lbc = nc.Dataset('/shared/netscratch/ptg21/UM_data/xgywn/xgywn_pm7-9.nc')
#extract variables to arrays
ch4_oh_lbc = data_lbc.variables['field34341'][:]*3 #moles per sec
#lat_lbc = data_lbc.variables['latitude'][:]
#lon_lbc = data_lbc.variables['longitude'][:]
#box_no_lbc = data_lbc.variables['model_level_number'][:]
#alt_lbc = data_lbc.variables['hybrid_ht'][:]
#mass_lbc = data_lbc.variables['field34363'][:]
press_lbc = data_lbc.variables['p']
trop_press_lbc = data_lbc.variables['p_3']

time_lbc = data_lbc.variables['t']
dtime_lbc = nc.num2date(time_lbc[:],time_lbc.units)

#ch4_lbc, lon_lbc = shiftgrid(180.,ch4_lbc,lon_lbc,start=False)

# %%
print(data_lbc.variables)
# Out:
# {'longitude': <class 'netCDF4._netCDF4.Variable'>
# float32 longitude(longitude)
#     units: degrees_east
#     point_spacing: even
#     modulo:
# unlimited dimensions:
# current shape = (96,)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'latitude': <class 'netCDF4._netCDF4.Variable'>
# float32 latitude(latitude)
#     units: degrees_north
#     point_spacing: even
# unlimited dimensions:
# current shape = (73,)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'hybrid_ht': <class 'netCDF4._netCDF4.Variable'>
# float32 hybrid_ht(hybrid_ht)
#     units: level
#     positive: up
# unlimited dimensions:
# current shape = (60,)
# filling on, default _FillValue of 9.969209968386869e+36 used, 't': <class 'netCDF4._netCDF4.Variable'>
# float32 t(t)
#     units: days since 2000-12-01 00:00:00
#     calendar: 360_day
#     time_origin: 01-DEC-2000:00:00:00
# unlimited dimensions: t
# current shape = (36,)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'theta': <class 'netCDF4._netCDF4.Variable'>
# float32 theta(t, hybrid_ht, latitude, longitude)
#     source: Unified Model Output (Vn 7.3):
#     name: theta
#     title: THETA AFTER TIMESTEP
#     date: 01/12/00
#     time: 00:00
#     long_name: THETA AFTER TIMESTEP
#     units: K
#     missing_value: 2e+20
#     _FillValue: 2e+20
#     valid_min: 214.17686
#     valid_max: 7991.1626
# unlimited dimensions: t
# current shape = (36, 60, 73, 96)
# filling on, 'q': <class 'netCDF4._netCDF4.Variable'>
# float32 q(t, hybrid_ht, latitude, longitude)
#     source: Unified Model Output (Vn 7.3):
#     name: q
#     title: SPECIFIC HUMIDITY AFTER TIMESTEP
#     date: 01/12/00
#     time: 00:00
#     long_name: SPECIFIC HUMIDITY AFTER TIMESTEP
#     units: kg kg-1
#     missing_value: 2e+20
#     _FillValue: 2e+20
#     valid_min: 6.335385e-07
#     valid_max: 0.022008253
# unlimited dimensions: t
# current shape = (36, 60, 73, 96)
# filling on, 'p': <class 'netCDF4._netCDF4.Variable'>
# float32 p(t, hybrid_ht, latitude, longitude)
#     source: Unified Model Output (Vn 7.3):
#     name: p
#     title: PRESSURE AT THETA LEVELS AFTER TS
#     date: 01/12/00
#     time: 00:00
#     long_name: PRESSURE AT THETA LEVELS AFTER TS
#     units: Pa
#     missing_value: 2e+20
#     _FillValue: 2e+20
#     valid_min: 0.14647202
#     valid_max: 104477.99
# unlimited dimensions: t
# current shape = (36, 60, 73, 96)
# filling on, 'temp': <class 'netCDF4._netCDF4.Variable'>
# float32 temp(t, hybrid_ht, latitude, longitude)
#     source: Unified Model Output (Vn 7.3):
#     name: temp
#     title: TEMPERATURE ON THETA LEVELS
#     date: 01/12/00
#     time: 00:00
#     long_name: TEMPERATURE ON THETA LEVELS
#     units: K
#     missing_value: 2e+20
#     _FillValue: 2e+20
#     valid_min: 133.22063
#     valid_max: 316.41974
# unlimited dimensions: t
# current shape = (36, 60, 73, 96)
# filling on, 'longitude_1': <class 'netCDF4._netCDF4.Variable'>
# float32 longitude_1(longitude_1)
#     units: degrees_east
#     point_spacing: even
#     modulo:
# unlimited dimensions:
# current shape = (96,)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'latitude_1': <class 'netCDF4._netCDF4.Variable'>
# float32 latitude_1(latitude_1)
#     units: degrees_north
#     point_spacing: even
# unlimited dimensions:
# current shape = (72,)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'p_1': <class 'netCDF4._netCDF4.Variable'>
# float32 p_1(p_1)
#     units: mbar
#     positive: down
# unlimited dimensions:
# current shape = (17,)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'u': <class 'netCDF4._netCDF4.Variable'>
# float32 u(t, p_1, latitude_1, longitude_1)
#     source: Unified Model Output (Vn 7.3):
#     name: u
#     title: U COMPNT OF WIND ON P LEV/UV GRID
#     date: 01/12/00
#     time: 00:00
#     long_name: U COMPNT OF WIND ON P LEV/UV GRID
#     units: m s-1
#     missing_value: 2e+20
#     _FillValue: 2e+20
#     valid_min: -49.450043
#     valid_max: 94.55557
# unlimited dimensions: t
# current shape = (36, 17, 72, 96)
# filling on, 'p_2': <class 'netCDF4._netCDF4.Variable'>
# float32 p_2(p_2)
#     units: mbar
#     positive: down
# unlimited dimensions:
# current shape = (33,)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'u_1': <class 'netCDF4._netCDF4.Variable'>
# float32 u_1(t, p_2, latitude_1, longitude_1)
#     source: Unified Model Output (Vn 7.3):
#     name: u_1
#     title: U COMPNT OF WIND ON P LEV/UV GRID
#     date: 01/12/00
#     time: 00:00
#     long_name: U COMPNT OF WIND ON P LEV/UV GRID
#     units: m s-1
#     missing_value: 2e+20
#     _FillValue: 2e+20
#     valid_min: -82.03218
#     valid_max: 139.33798
# unlimited dimensions: t
# current shape = (36, 33, 72, 96)
# filling on, 'ht': <class 'netCDF4._netCDF4.Variable'>
# float32 ht(ht)
#     units: m
#     positive: up
# unlimited dimensions:
# current shape = (1,)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'p_3': <class 'netCDF4._netCDF4.Variable'>
# float32 p_3(t, ht, latitude, longitude)
#     source: Unified Model Output (Vn 7.3):
#     name: p_3
#     title: Pressure at Tropopause Level
#     date: 01/12/00
#     time: 00:00
#     long_name: Pressure at Tropopause Level
#     units: Pa
#     missing_value: 2e+20
#     _FillValue: 2e+20
#     valid_min: 7686.0576
#     valid_max: 33402.453
# unlimited dimensions: t
# current shape = (36, 1, 73, 96)
# filling on, 'ht_1': <class 'netCDF4._netCDF4.Variable'>
# float32 ht_1(t, ht, latitude, longitude)
#     source: Unified Model Output (Vn 7.3):
#     name: ht_1
#     title: Height at Tropopause Level
#     date: 01/12/00
#     time: 00:00
#     long_name: Height at Tropopause Level
#     units: m
#     missing_value: 2e+20
#     _FillValue: 2e+20
#     valid_min: 4119.6772
#     valid_max: 18105.82
# unlimited dimensions: t
# current shape = (36, 1, 73, 96)
# filling on, 'field34001': <class 'netCDF4._netCDF4.Variable'>
# float32 field34001(t, hybrid_ht, latitude, longitude)
#     source: Unified Model Output (Vn 7.3):
#     name: field34001
#     title: O3 MASS MIXING RATIO AFTER TIMESTEP
#     date: 01/12/00
#     time: 00:00
#     long_name: O3 MASS MIXING RATIO AFTER TIMESTEP
#     units:
#     missing_value: 2e+20
#     _FillValue: 2e+20
#     valid_min: 1.0696122e-09
#     valid_max: 1.9410036e-05
# unlimited dimensions: t
# current shape = (36, 60, 73, 96)
# filling on, 'field34002': <class 'netCDF4._netCDF4.Variable'>
# float32 field34002(t, hybrid_ht, latitude, longitude)
#     source: Unified Model Output (Vn 7.3):
#     name: field34002
#     title: NO MASS MIXING RATIO AFTER TIMESTEP
#     date: 01/12/00
#     time: 00:00
#     long_name: NO MASS MIXING RATIO AFTER TIMESTEP
#     units:
#     missing_value: 2e+20
#     _FillValue: 2e+20
#     valid_min: 1.3529763e-28
#     valid_max: 6.048653e-08
# unlimited dimensions: t
# current shape = (36, 60, 73, 96)
# filling on, 'field34004': <class 'netCDF4._netCDF4.Variable'>
# float32 field34004(t, hybrid_ht, latitude, longitude)
#     source: Unified Model Output (Vn 7.3):
#     name: field34004
#     title: NO2 MASS MIXING RATIO AFTER TIMESTEP
#     date: 01/12/00
#     time: 00:00
#     long_name: NO2 MASS MIXING RATIO AFTER TIMESTEP
#     units:
#     missing_value: 2e+20
#     _FillValue: 2e+20
#     valid_min: 3.1839973e-12
#     valid_max: 1.3347933e-07
# unlimited dimensions: t
# current shape = (36, 60, 73, 96)
# filling on, 'field34007': <class 'netCDF4._netCDF4.Variable'>
# float32 field34007(t, hybrid_ht, latitude, longitude)
#     source: Unified Model Output (Vn 7.3):
#     name: field34007
#     title: HONO2 MASS MIXING RATIO AFTER TSTEP
#     date: 01/12/00
#     time: 00:00
#     long_name: HONO2 MASS MIXING RATIO AFTER TSTEP
#     units:
#     missing_value: 2e+20
#     _FillValue: 2e+20
#     valid_min: 6.346176e-15
#     valid_max: 2.6342867e-08
# unlimited dimensions: t
# current shape = (36, 60, 73, 96)
# filling on, 'field34008': <class 'netCDF4._netCDF4.Variable'>
# float32 field34008(t, hybrid_ht, latitude, longitude)
#     source: Unified Model Output (Vn 7.3):
#     name: field34008
#     title: H2O2 MASS MIXING RATIO AFTER TSTEP
#     date: 01/12/00
#     time: 00:00
#     long_name: H2O2 MASS MIXING RATIO AFTER TSTEP
#     units:
#     missing_value: 2e+20
#     _FillValue: 2e+20
#     valid_min: 2.3614663e-13
#     valid_max: 1.3898223e-08
# unlimited dimensions: t
# current shape = (36, 60, 73, 96)
# filling on, 'field34009': <class 'netCDF4._netCDF4.Variable'>
# float32 field34009(t, hybrid_ht, latitude, longitude)
#     source: Unified Model Output (Vn 7.3):
#     name: field34009
#     title: CH4 MASS MIXING RATIO AFTER TSTEP
#     date: 01/12/00
#     time: 00:00
#     long_name: CH4 MASS MIXING RATIO AFTER TSTEP
#     units:
#     missing_value: 2e+20
#     _FillValue: 2e+20
#     valid_min: 1.6483602e-08
#     valid_max: 9.72e-07
# unlimited dimensions: t
# current shape = (36, 60, 73, 96)
# filling on, 'field34010': <class 'netCDF4._netCDF4.Variable'>
# float32 field34010(t, hybrid_ht, latitude, longitude)
#     source: Unified Model Output (Vn 7.3):
#     name: field34010
#     title: CO MASS MIXING RATIO AFTER TSTEP
#     date: 01/12/00
#     time: 00:00
#     long_name: CO MASS MIXING RATIO AFTER TSTEP
#     units:
#     missing_value: 2e+20
#     _FillValue: 2e+20
#     valid_min: 2.7056561e-09
#     valid_max: 5.4826983e-06
# unlimited dimensions: t
# current shape = (36, 60, 73, 96)
# filling on, 'field34011': <class 'netCDF4._netCDF4.Variable'>
# float32 field34011(t, hybrid_ht, latitude, longitude)
#     source: Unified Model Output (Vn 7.3):
#     name: field34011
#     title: HCHO MASS MIXING RATIO AFTER TSTEP
#     date: 01/12/00
#     time: 00:00
#     long_name: HCHO MASS MIXING RATIO AFTER TSTEP
#     units:
#     missing_value: 2e+20
#     _FillValue: 2e+20
#     valid_min: 1.6916342e-13
#     valid_max: 2.1626041e-08
# unlimited dimensions: t
# current shape = (36, 60, 73, 96)
# filling on, 'field34012': <class 'netCDF4._netCDF4.Variable'>
# float32 field34012(t, hybrid_ht, latitude, longitude)
#     source: Unified Model Output (Vn 7.3):
#     name: field34012
#     title: MeOOH MASS MIXING RATIO AFTER TSTEP
#     date: 01/12/00
#     time: 00:00
#     long_name: MeOOH MASS MIXING RATIO AFTER TSTEP
#     units:
#     missing_value: 2e+20
#     _FillValue: 2e+20
#     valid_min: 1.0094085e-13
#     valid_max: 1.0608029e-08
# unlimited dimensions: t
# current shape = (36, 60, 73, 96)
# filling on, 'field34014': <class 'netCDF4._netCDF4.Variable'>
# float32 field34014(t, hybrid_ht, latitude, longitude)
#     source: Unified Model Output (Vn 7.3):
#     name: field34014
#     title: C2H6 MASS MIXING RATIO AFTER TSTEP
#     date: 01/12/00
#     time: 00:00
#     long_name: C2H6 MASS MIXING RATIO AFTER TSTEP
#     units:
#     missing_value: 2e+20
#     _FillValue: 2e+20
#     valid_min: 1.0528612e-25
#     valid_max: 1.2662854e-07
# unlimited dimensions: t
# current shape = (36, 60, 73, 96)
# filling on, 'field34015': <class 'netCDF4._netCDF4.Variable'>
# float32 field34015(t, hybrid_ht, latitude, longitude)
#     source: Unified Model Output (Vn 7.3):
#     name: field34015
#     title: EtOOH MASS MIXING RATIO AFTER TSTEP
#     date: 01/12/00
#     time: 00:00
#     long_name: EtOOH MASS MIXING RATIO AFTER TSTEP
#     units:
#     missing_value: 2e+20
#     _FillValue: 2e+20
#     valid_min: 1.4056106e-27
#     valid_max: 4.1060325e-10
# unlimited dimensions: t
# current shape = (36, 60, 73, 96)
# filling on, 'field34016': <class 'netCDF4._netCDF4.Variable'>
# float32 field34016(t, hybrid_ht, latitude, longitude)
#     source: Unified Model Output (Vn 7.3):
#     name: field34016
#     title: MeCHO MASS MIXING RATIO AFTER TSTEP
#     date: 01/12/00
#     time: 00:00
#     long_name: MeCHO MASS MIXING RATIO AFTER TSTEP
#     units:
#     missing_value: 2e+20
#     _FillValue: 2e+20
#     valid_min: 1.5567091e-26
#     valid_max: 6.094495e-08
# unlimited dimensions: t
# current shape = (36, 60, 73, 96)
# filling on, 'field34017': <class 'netCDF4._netCDF4.Variable'>
# float32 field34017(t, hybrid_ht, latitude, longitude)
#     source: Unified Model Output (Vn 7.3):
#     name: field34017
#     title: PAN MASS MIXING RATIO AFTER TSTEP
#     date: 01/12/00
#     time: 00:00
#     long_name: PAN MASS MIXING RATIO AFTER TSTEP
#     units:
#     missing_value: 2e+20
#     _FillValue: 2e+20
#     valid_min: 4.9463927e-29
#     valid_max: 3.3394347e-08
# unlimited dimensions: t
# current shape = (36, 60, 73, 96)
# filling on, 'field34018': <class 'netCDF4._netCDF4.Variable'>
# float32 field34018(t, hybrid_ht, latitude, longitude)
#     source: Unified Model Output (Vn 7.3):
#     name: field34018
#     title: C3H8 MASS MIXING RATIO AFTER TSTEP
#     date: 01/12/00
#     time: 00:00
#     long_name: C3H8 MASS MIXING RATIO AFTER TSTEP
#     units:
#     missing_value: 2e+20
#     _FillValue: 2e+20
#     valid_min: 1.874082e-34
#     valid_max: 9.801972e-08
# unlimited dimensions: t
# current shape = (36, 60, 73, 96)
# filling on, 'field34021': <class 'netCDF4._netCDF4.Variable'>
# float32 field34021(t, hybrid_ht, latitude, longitude)
#     source: Unified Model Output (Vn 7.3):
#     name: field34021
#     title: EtCHO MASS MIXING RATIO AFTER TSTEP
#     date: 01/12/00
#     time: 00:00
#     long_name: EtCHO MASS MIXING RATIO AFTER TSTEP
#     units:
#     missing_value: 2e+20
#     _FillValue: 2e+20
#     valid_min: 3.360705e-36
#     valid_max: 2.9269392e-10
# unlimited dimensions: t
# current shape = (36, 60, 73, 96)
# filling on, 'field34022': <class 'netCDF4._netCDF4.Variable'>
# float32 field34022(t, hybrid_ht, latitude, longitude)
#     source: Unified Model Output (Vn 7.3):
#     name: field34022
#     title: Me2CO MASS MIXING RATIO AFTER TSTEP
#     date: 01/12/00
#     time: 00:00
#     long_name: Me2CO MASS MIXING RATIO AFTER TSTEP
#     units:
#     missing_value: 2e+20
#     _FillValue: 2e+20
#     valid_min: 2.1204265e-34
#     valid_max: 5.35207e-08
# unlimited dimensions: t
# current shape = (36, 60, 73, 96)
# filling on, 'field34027': <class 'netCDF4._netCDF4.Variable'>
# float32 field34027(t, hybrid_ht, latitude, longitude)
#     source: Unified Model Output (Vn 7.3):
#     name: field34027
#     title: C5H8 MASS MIXING RATIO AFTER TSTEP
#     date: 01/12/00
#     time: 00:00
#     long_name: C5H8 MASS MIXING RATIO AFTER TSTEP
#     units:
#     missing_value: 2e+20
#     _FillValue: 2e+20
#     valid_min: 0.0
#     valid_max: 5.316911e-08
# unlimited dimensions: t
# current shape = (36, 60, 73, 96)
# filling on, 'field34041': <class 'netCDF4._netCDF4.Variable'>
# float32 field34041(t, hybrid_ht, latitude, longitude)
#     source: Unified Model Output (Vn 7.3):
#     name: field34041
#     title: Cl MASS MIXING RATIO AFTER TIMESTEP
#     date: 01/12/00
#     time: 00:00
#     long_name: Cl MASS MIXING RATIO AFTER TIMESTEP
#     units:
#     missing_value: 2e+20
#     _FillValue: 2e+20
#     valid_min: 3.0831627e-26
#     valid_max: 3.4833525e-10
# unlimited dimensions: t
# current shape = (36, 60, 73, 96)
# filling on, 'field34042': <class 'netCDF4._netCDF4.Variable'>
# float32 field34042(t, hybrid_ht, latitude, longitude)
#     source: Unified Model Output (Vn 7.3):
#     name: field34042
#     title: ClO MASS MIXING RATIO AFTER TSTEP
#     date: 01/12/00
#     time: 00:00
#     long_name: ClO MASS MIXING RATIO AFTER TSTEP
#     units:
#     missing_value: 2e+20
#     _FillValue: 2e+20
#     valid_min: 5.782016e-24
#     valid_max: 1.6566967e-09
# unlimited dimensions: t
# current shape = (36, 60, 73, 96)
# filling on, 'field34045': <class 'netCDF4._netCDF4.Variable'>
# float32 field34045(t, hybrid_ht, latitude, longitude)
#     source: Unified Model Output (Vn 7.3):
#     name: field34045
#     title: Br MASS MIXING RATIO AFTER TIMESTEP
#     date: 01/12/00
#     time: 00:00
#     long_name: Br MASS MIXING RATIO AFTER TIMESTEP
#     units:
#     missing_value: 2e+20
#     _FillValue: 2e+20
#     valid_min: 2.7981903e-23
#     valid_max: 5.7765463e-11
# unlimited dimensions: t
# current shape = (36, 60, 73, 96)
# filling on, 'field34046': <class 'netCDF4._netCDF4.Variable'>
# float32 field34046(t, hybrid_ht, latitude, longitude)
#     source: Unified Model Output (Vn 7.3):
#     name: field34046
#     title: BrO MASS MIXING RATIO AFTER TIMESTEP
#     date: 01/12/00
#     time: 00:00
#     long_name: BrO MASS MIXING RATIO AFTER TIMESTEP
#     units:
#     missing_value: 2e+20
#     _FillValue: 2e+20
#     valid_min: 6.684826e-11
#     valid_max: 7.484686e-11
# unlimited dimensions: t
# current shape = (36, 60, 73, 96)
# filling on, 'field34049': <class 'netCDF4._netCDF4.Variable'>
# float32 field34049(t, hybrid_ht, latitude, longitude)
#     source: Unified Model Output (Vn 7.3):
#     name: field34049
#     title: N2O MASS MIXING RATIO AFTER TIMESTEP
#     date: 01/12/00
#     time: 00:00
#     long_name: N2O MASS MIXING RATIO AFTER TIMESTEP
#     units:
#     missing_value: 2e+20
#     _FillValue: 2e+20
#     valid_min: 1.3330054e-11
#     valid_max: 4.8e-07
# unlimited dimensions: t
# current shape = (36, 60, 73, 96)
# filling on, 'field34050': <class 'netCDF4._netCDF4.Variable'>
# float32 field34050(t, hybrid_ht, latitude, longitude)
#     source: Unified Model Output (Vn 7.3):
#     name: field34050
#     title: HCl MASS MIXING RATIO AFTER TIMESTEP
#     date: 01/12/00
#     time: 00:00
#     long_name: HCl MASS MIXING RATIO AFTER TIMESTEP
#     units:
#     missing_value: 2e+20
#     _FillValue: 2e+20
#     valid_min: 4.283625e-09
#     valid_max: 4.325379e-09
# unlimited dimensions: t
# current shape = (36, 60, 73, 96)
# filling on, 'field34054': <class 'netCDF4._netCDF4.Variable'>
# float32 field34054(t, hybrid_ht, latitude, longitude)
#     source: Unified Model Output (Vn 7.3):
#     name: field34054
#     title: ClONO2 MASS MIXING RATIO AFTER TSTEP
#     date: 01/12/00
#     time: 00:00
#     long_name: ClONO2 MASS MIXING RATIO AFTER TSTEP
#     units:
#     missing_value: 2e+20
#     _FillValue: 2e+20
#     valid_min: 3.7399397e-23
#     valid_max: 6.199352e-09
# unlimited dimensions: t
# current shape = (36, 60, 73, 96)
# filling on, 'field34081': <class 'netCDF4._netCDF4.Variable'>
# float32 field34081(t, hybrid_ht, latitude, longitude)
#     source: Unified Model Output (Vn 7.3):
#     name: field34081
#     title: OH MASS MIXING RATIO AFTER TIMESTEP
#     date: 01/12/00
#     time: 00:00
#     long_name: OH MASS MIXING RATIO AFTER TIMESTEP
#     units:
#     missing_value: 2e+20
#     _FillValue: 2e+20
#     valid_min: 2.2938271e-20
#     valid_max: 3.2240755e-09
# unlimited dimensions: t
# current shape = (36, 60, 73, 96)
# filling on, 'field34082': <class 'netCDF4._netCDF4.Variable'>
# float32 field34082(t, hybrid_ht, latitude, longitude)
#     source: Unified Model Output (Vn 7.3):
#     name: field34082
#     title: HO2 MASS MIXING RATIO AFTER TIMESTEP
#     date: 01/12/00
#     time: 00:00
#     long_name: HO2 MASS MIXING RATIO AFTER TIMESTEP
#     units:
#     missing_value: 2e+20
#     _FillValue: 2e+20
#     valid_min: 5.9954413e-19
#     valid_max: 2.932429e-09
# unlimited dimensions: t
# current shape = (36, 60, 73, 96)
# filling on, 'field34094': <class 'netCDF4._netCDF4.Variable'>
# float32 field34094(t, hybrid_ht, latitude, longitude)
#     source: Unified Model Output (Vn 7.3):
#     name: field34094
#     title: SO3 MASS MIXING RATIO AFTER TIMESTEP
#     date: 01/12/00
#     time: 00:00
#     long_name: SO3 MASS MIXING RATIO AFTER TIMESTEP
#     units:
#     missing_value: 2e+20
#     _FillValue: 2e+20
#     valid_min: 1.143764e-15
#     valid_max: 2.5801458e-07
# unlimited dimensions: t
# current shape = (36, 60, 73, 96)
# filling on, 'field34150': <class 'netCDF4._netCDF4.Variable'>
# float32 field34150(t, hybrid_ht, latitude, longitude)
#     source: Unified Model Output (Vn 7.3):
#     name: field34150
#     title: AGE OF AIR IN SECONDS
#     date: 01/12/00
#     time: 00:00
#     long_name: AGE OF AIR IN SECONDS
#     units:
#     missing_value: 2e+20
#     _FillValue: 2e+20
#     valid_min: 0.0
#     valid_max: 141855180.0
# unlimited dimensions: t
# current shape = (36, 60, 73, 96)
# filling on, 'field34151': <class 'netCDF4._netCDF4.Variable'>
# float32 field34151(t, hybrid_ht, latitude, longitude)
#     source: Unified Model Output (Vn 7.3):
#     name: field34151
#     title: O(1D) MASS MIXING RATIO
#     date: 01/12/00
#     time: 00:00
#     long_name: O(1D) MASS MIXING RATIO
#     units:
#     missing_value: 2e+20
#     _FillValue: 2e+20
#     valid_min: 0.0
#     valid_max: 6.9833184e-14
# unlimited dimensions: t
# current shape = (36, 60, 73, 96)
# filling on, 'field34152': <class 'netCDF4._netCDF4.Variable'>
# float32 field34152(t, hybrid_ht, latitude, longitude)
#     source: Unified Model Output (Vn 7.3):
#     name: field34152
#     title: O(3P) MASS MIXING RATIO
#     date: 01/12/00
#     time: 00:00
#     long_name: O(3P) MASS MIXING RATIO
#     units:
#     missing_value: 2e+20
#     _FillValue: 2e+20
#     valid_min: 1.7365428e-17
#     valid_max: 5.110494e-08
# unlimited dimensions: t
# current shape = (36, 60, 73, 96)
# filling on, 'field34153': <class 'netCDF4._netCDF4.Variable'>
# float32 field34153(t, hybrid_ht, latitude, longitude)
#     source: Unified Model Output (Vn 7.3):
#     name: field34153
#     title: NO2 MASS MIXING RATIO AFTER TSTEP
#     date: 01/12/00
#     time: 00:00
#     long_name: NO2 MASS MIXING RATIO AFTER TSTEP
#     units:
#     missing_value: 2e+20
#     _FillValue: 2e+20
#     valid_min: 6.620012e-19
#     valid_max: 5.9591165e-11
# unlimited dimensions: t
# current shape = (36, 60, 73, 96)
# filling on, 'field34154': <class 'netCDF4._netCDF4.Variable'>
# float32 field34154(t, hybrid_ht, latitude, longitude)
#     source: Unified Model Output (Vn 7.3):
#     name: field34154
#     title: BrO MASS MIXING RATIO AFTER TSTEP
#     date: 01/12/00
#     time: 00:00
#     long_name: BrO MASS MIXING RATIO AFTER TSTEP
#     units:
#     missing_value: 2e+20
#     _FillValue: 2e+20
#     valid_min: 3.3021066e-16
#     valid_max: 4.240165e-09
# unlimited dimensions: t
# current shape = (36, 60, 73, 96)
# filling on, 'field34155': <class 'netCDF4._netCDF4.Variable'>
# float32 field34155(t, hybrid_ht, latitude, longitude)
#     source: Unified Model Output (Vn 7.3):
#     name: field34155
#     title: HCl MASS MIXING RATIO AFTER TSTEP
#     date: 01/12/00
#     time: 00:00
#     long_name: HCl MASS MIXING RATIO AFTER TSTEP
#     units:
#     missing_value: 2e+20
#     _FillValue: 2e+20
#     valid_min: 3.6712584e-16
#     valid_max: 4.315461e-09
# unlimited dimensions: t
# current shape = (36, 60, 73, 96)
# filling on, 'field34301': <class 'netCDF4._netCDF4.Variable'>
# float32 field34301(t, hybrid_ht, latitude, longitude)
#     source: Unified Model Output (Vn 7.3):
#     name: field34301
#     title: Ox PROD: HO2+NO
#     date: 01/12/00
#     time: 00:00
#     long_name: Ox PROD: HO2+NO
#     units:
#     missing_value: 2e+20
#     _FillValue: 2e+20
#     valid_min: 1.3135152e-25
#     valid_max: 347.03687
# unlimited dimensions: t
# current shape = (36, 60, 73, 96)
# filling on, 'field34302': <class 'netCDF4._netCDF4.Variable'>
# float32 field34302(t, hybrid_ht, latitude, longitude)
#     source: Unified Model Output (Vn 7.3):
#     name: field34302
#     title: Ox PROD: MeOO+NO
#     date: 01/12/00
#     time: 00:00
#     long_name: Ox PROD: MeOO+NO
#     units:
#     missing_value: 2e+20
#     _FillValue: 2e+20
#     valid_min: 1.0990649e-24
#     valid_max: 61.320065
# unlimited dimensions: t
# current shape = (36, 60, 73, 96)
# filling on, 'field34303': <class 'netCDF4._netCDF4.Variable'>
# float32 field34303(t, hybrid_ht, latitude, longitude)
#     source: Unified Model Output (Vn 7.3):
#     name: field34303
#     title: Ox PROD: NO+RO2
#     date: 01/12/00
#     time: 00:00
#     long_name: Ox PROD: NO+RO2
#     units:
#     missing_value: 2e+20
#     _FillValue: 2e+20
#     valid_min: 3.5290845e-26
#     valid_max: 95.874626
# unlimited dimensions: t
# current shape = (36, 60, 73, 96)
# filling on, 'field34304': <class 'netCDF4._netCDF4.Variable'>
# float32 field34304(t, hybrid_ht, latitude, longitude)
#     source: Unified Model Output (Vn 7.3):
#     name: field34304
#     title: Ox PROD: OH+INORGANIC ACID
#     date: 01/12/00
#     time: 00:00
#     long_name: Ox PROD: OH+INORGANIC ACID
#     units:
#     missing_value: 2e+20
#     _FillValue: 2e+20
#     valid_min: 1.095232e-15
#     valid_max: 1.985381
# unlimited dimensions: t
# current shape = (36, 60, 73, 96)
# filling on, 'field34305': <class 'netCDF4._netCDF4.Variable'>
# float32 field34305(t, hybrid_ht, latitude, longitude)
#     source: Unified Model Output (Vn 7.3):
#     name: field34305
#     title: Ox PROD: OH+ORGANIC NITRATE
#     date: 01/12/00
#     time: 00:00
#     long_name: Ox PROD: OH+ORGANIC NITRATE
#     units:
#     missing_value: 2e+20
#     _FillValue: 2e+20
#     valid_min: 1.3982805e-17
#     valid_max: 5.32646
# unlimited dimensions: t
# current shape = (36, 60, 73, 96)
# filling on, 'field34306': <class 'netCDF4._netCDF4.Variable'>
# float32 field34306(t, hybrid_ht, latitude, longitude)
#     source: Unified Model Output (Vn 7.3):
#     name: field34306
#     title: Ox PROD: ORGANIC NITRATE PHOTOLYSIS
#     date: 01/12/00
#     time: 00:00
#     long_name: Ox PROD: ORGANIC NITRATE PHOTOLYSIS
#     units:
#     missing_value: 2e+20
#     _FillValue: 2e+20
#     valid_min: 0.0
#     valid_max: 0.3859135
# unlimited dimensions: t
# current shape = (36, 60, 73, 96)
# filling on, 'field34307': <class 'netCDF4._netCDF4.Variable'>
# float32 field34307(t, hybrid_ht, latitude, longitude)
#     source: Unified Model Output (Vn 7.3):
#     name: field34307
#     title: Ox PROD: OH + PAN-TYPE REACTIONS
#     date: 01/12/00
#     time: 00:00
#     long_name: Ox PROD: OH + PAN-TYPE REACTIONS
#     units:
#     missing_value: 2e+20
#     _FillValue: 2e+20
#     valid_min: 2.8849915e-28
#     valid_max: 23.888939
# unlimited dimensions: t
# current shape = (36, 60, 73, 96)
# filling on, 'field34311': <class 'netCDF4._netCDF4.Variable'>
# float32 field34311(t, hybrid_ht, latitude, longitude)
#     source: Unified Model Output (Vn 7.3):
#     name: field34311
#     title: Ox LOSS: O(1D)+H2O
#     date: 01/12/00
#     time: 00:00
#     long_name: Ox LOSS: O(1D)+H2O
#     units:
#     missing_value: 2e+20
#     _FillValue: 2e+20
#     valid_min: 0.0
#     valid_max: 76.17536
# unlimited dimensions: t
# current shape = (36, 60, 73, 96)
# filling on, 'field34312': <class 'netCDF4._netCDF4.Variable'>
# float32 field34312(t, hybrid_ht, latitude, longitude)
#     source: Unified Model Output (Vn 7.3):
#     name: field34312
#     title: Ox LOSS: MINOR LOSS REACTIONS
#     date: 01/12/00
#     time: 00:00
#     long_name: Ox LOSS: MINOR LOSS REACTIONS
#     units:
#     missing_value: 2e+20
#     _FillValue: 2e+20
#     valid_min: 1.6263401e-26
#     valid_max: 410.3364
# unlimited dimensions: t
# current shape = (36, 60, 73, 96)
# filling on, 'field34313': <class 'netCDF4._netCDF4.Variable'>
# float32 field34313(t, hybrid_ht, latitude, longitude)
#     source: Unified Model Output (Vn 7.3):
#     name: field34313
#     title: Ox LOSS: HO2+O3
#     date: 01/12/00
#     time: 00:00
#     long_name: Ox LOSS: HO2+O3
#     units:
#     missing_value: 2e+20
#     _FillValue: 2e+20
#     valid_min: 1.7991395e-11
#     valid_max: 47.154167
# unlimited dimensions: t
# current shape = (36, 60, 73, 96)
# filling on, 'field34314': <class 'netCDF4._netCDF4.Variable'>
# float32 field34314(t, hybrid_ht, latitude, longitude)
#     source: Unified Model Output (Vn 7.3):
#     name: field34314
#     title: Ox LOSS: OH+O3
#     date: 01/12/00
#     time: 00:00
#     long_name: Ox LOSS: OH+O3
#     units:
#     missing_value: 2e+20
#     _FillValue: 2e+20
#     valid_min: 1.6247004e-10
#     valid_max: 34.29347
# unlimited dimensions: t
# current shape = (36, 60, 73, 96)
# filling on, 'field34315': <class 'netCDF4._netCDF4.Variable'>
# float32 field34315(t, hybrid_ht, latitude, longitude)
#     source: Unified Model Output (Vn 7.3):
#     name: field34315
#     title: Ox LOSS: O3+ALKENE
#     date: 01/12/00
#     time: 00:00
#     long_name: Ox LOSS: O3+ALKENE
#     units:
#     missing_value: 2e+20
#     _FillValue: 2e+20
#     valid_min: 0.0
#     valid_max: 26.609114
# unlimited dimensions: t
# current shape = (36, 60, 73, 96)
# filling on, 'field34316': <class 'netCDF4._netCDF4.Variable'>
# float32 field34316(t, hybrid_ht, latitude, longitude)
#     source: Unified Model Output (Vn 7.3):
#     name: field34316
#     title: Ox LOSS: N2O5+H2O
#     date: 01/12/00
#     time: 00:00
#     long_name: Ox LOSS: N2O5+H2O
#     units:
#     missing_value: 2e+20
#     _FillValue: 2e+20
#     valid_min: 1.2031755e-33
#     valid_max: 3.4400039
# unlimited dimensions: t
# current shape = (36, 60, 73, 96)
# filling on, 'field34317': <class 'netCDF4._netCDF4.Variable'>
# float32 field34317(t, hybrid_ht, latitude, longitude)
#     source: Unified Model Output (Vn 7.3):
#     name: field34317
#     title: Ox LOSS: NO3 CHEMICAL LOSS
#     date: 01/12/00
#     time: 00:00
#     long_name: Ox LOSS: NO3 CHEMICAL LOSS
#     units:
#     missing_value: 2e+20
#     _FillValue: 2e+20
#     valid_min: 4.371189e-15
#     valid_max: 19.30869
# unlimited dimensions: t
# current shape = (36, 60, 73, 96)
# filling on, 'surface': <class 'netCDF4._netCDF4.Variable'>
# float32 surface(surface)
#     units: level
#     positive: up
# unlimited dimensions:
# current shape = (1,)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'field34321': <class 'netCDF4._netCDF4.Variable'>
# float32 field34321(t, surface, latitude, longitude)
#     source: Unified Model Output (Vn 7.3):
#     name: field34321
#     title: Ox BUDGET: O3 DRY DEPOSITION (3D)
#     date: 01/12/00
#     time: 00:00
#     long_name: Ox BUDGET: O3 DRY DEPOSITION (3D)
#     units:
#     missing_value: 2e+20
#     _FillValue: 2e+20
#     valid_min: 0.020154784
#     valid_max: 436.2345
# unlimited dimensions: t
# current shape = (36, 1, 73, 96)
# filling on, 'field34322': <class 'netCDF4._netCDF4.Variable'>
# float32 field34322(t, surface, latitude, longitude)
#     source: Unified Model Output (Vn 7.3):
#     name: field34322
#     title: Ox BUDGET: NOy DRY DEPOSITION (3D)
#     date: 01/12/00
#     time: 00:00
#     long_name: Ox BUDGET: NOy DRY DEPOSITION (3D)
#     units:
#     missing_value: 2e+20
#     _FillValue: 2e+20
#     valid_min: 5.9505925e-05
#     valid_max: 87.823494
# unlimited dimensions: t
# current shape = (36, 1, 73, 96)
# filling on, 'field34331': <class 'netCDF4._netCDF4.Variable'>
# float32 field34331(t, hybrid_ht, latitude, longitude)
#     source: Unified Model Output (Vn 7.3):
#     name: field34331
#     title: Ox BUDGET: NOy WET DEPOSITION (3D)
#     date: 01/12/00
#     time: 00:00
#     long_name: Ox BUDGET: NOy WET DEPOSITION (3D)
#     units:
#     missing_value: 2e+20
#     _FillValue: 2e+20
#     valid_min: 0.0
#     valid_max: 19.28459
# unlimited dimensions: t
# current shape = (36, 60, 73, 96)
# filling on, 'field34341': <class 'netCDF4._netCDF4.Variable'>
# float32 field34341(t, hybrid_ht, latitude, longitude)
#     source: Unified Model Output (Vn 7.3):
#     name: field34341
#     title: RXN FLUX: OH+CH4 (CH4 LIFETIME) TROP
#     date: 01/12/00
#     time: 00:00
#     long_name: RXN FLUX: OH+CH4 (CH4 LIFETIME) TROP
#     units:
#     missing_value: 2e+20
#     _FillValue: 2e+20
#     valid_min: 2.2552907e-13
#     valid_max: 26.960114
# unlimited dimensions: t
# current shape = (36, 60, 73, 96)
# filling on, 'field34351': <class 'netCDF4._netCDF4.Variable'>
# float32 field34351(t, hybrid_ht, latitude, longitude)
#     source: Unified Model Output (Vn 7.3):
#     name: field34351
#     title: STE: O3
#     date: 01/12/00
#     time: 00:00
#     long_name: STE: O3
#     units:
#     missing_value: 2e+20
#     _FillValue: 2e+20
#     valid_min: -1025.1647
#     valid_max: 554.13824
# unlimited dimensions: t
# current shape = (36, 60, 73, 96)
# filling on, 'field34354': <class 'netCDF4._netCDF4.Variable'>
# float32 field34354(t, hybrid_ht, latitude, longitude)
#     source: Unified Model Output (Vn 7.3):
#     name: field34354
#     title: TENDENCY: O3 (WHOLE ATMOS)
#     date: 01/12/00
#     time: 00:00
#     long_name: TENDENCY: O3 (WHOLE ATMOS)
#     units:
#     missing_value: 2e+20
#     _FillValue: 2e+20
#     valid_min: -985.9997
#     valid_max: 1072.7845
# unlimited dimensions: t
# current shape = (36, 60, 73, 96)
# filling on, 'field34363': <class 'netCDF4._netCDF4.Variable'>
# float32 field34363(t, hybrid_ht, latitude, longitude)
#     source: Unified Model Output (Vn 7.3):
#     name: field34363
#     title: AIR MASS DIAGNOSTIC (WHOLE ATMOS)
#     date: 01/12/00
#     time: 00:00
#     long_name: AIR MASS DIAGNOSTIC (WHOLE ATMOS)
#     units:
#     missing_value: 2e+20
#     _FillValue: 2e+20
#     valid_min: 7762286.5
#     valid_max: 52973506000000.0
# unlimited dimensions: t
# current shape = (36, 60, 73, 96)
# filling on, 'field34381': <class 'netCDF4._netCDF4.Variable'>
# float32 field34381(t, hybrid_ht, latitude, longitude)
#     source: Unified Model Output (Vn 7.3):
#     name: field34381
#     title: LIGHTNING NOx EMISSIONS 3D
#     date: 01/12/00
#     time: 00:00
#     long_name: LIGHTNING NOx EMISSIONS 3D
#     units:
#     missing_value: 2e+20
#     _FillValue: 2e+20
#     valid_min: 0.0
#     valid_max: 16.36531
# unlimited dimensions: t
# current shape = (36, 60, 73, 96)
# filling on}

# %% [markdown]
# ## Make tropospheric mask

# %%
trop_mask_xg = MA.masked_where(press_lbc < trop_press_lbc[:], press_lbc)

# %%
trop_mask_xl = MA.masked_where(press_xl < trop_press_xl[:][:,None,:,:], press_xl) #add extra dimension
#print(press_lbc)

# %% [markdown]
# ## CH4 OH flux calc

# %%
#xltln
ch4_oh_tg_yr = ch4_oh*mr_ch4*per_sec_to_per_yr/g_to_Tg
ch4_oh_trop_xl = MA.masked_where(trop_mask_xl.mask,ch4_oh_tg_yr)
#sum over lat lon alt
flux_sum_xl = np.sum(ch4_oh_trop_xl, axis=(1,2,3))

# %%
fig = plt.figure(dpi=150)
ax = plt.axes()
ax.plot(dtime,flux_sum_xl)
plt.xlabel('Time')
plt.ylabel('CH4 OH flux / Tg yr-1')
plt.title(f'CH4 OH flux over time (xltln)')
# Out:
# Text(0.5, 1.0, 'CH4 OH flux over time (xltln)')

# %%
#xgywn
ch4_oh_lbc_tg_yr = ch4_oh_lbc*mr_ch4*per_sec_to_per_yr/g_to_Tg
ch4_oh_trop_xg = MA.masked_where(trop_mask_xg.mask,ch4_oh_lbc_tg_yr)
#sum over lat lon alt
flux_sum_xg = np.sum(ch4_oh_trop_xg, axis=(1,2,3))

# %%
fig = plt.figure(dpi=150)
ax = plt.axes()
ax.plot(dtime_lbc,flux_sum_xg)
plt.xlabel('Time')
plt.ylabel('CH4 OH flux / Tg yr-1')
plt.title(f'CH4 OH flux over time (xgywn)')
# Out:
# Text(0.5, 1.0, 'CH4 OH flux over time (xgywn)')
